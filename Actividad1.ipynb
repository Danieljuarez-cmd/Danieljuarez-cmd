# %% [markdown]
# <a href="https://colab.research.google.com/github/Danieljuarez-cmd/Danieljuarez-cmd/blob/main/Actividad1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <font color="green">  "GRAFICA DE LA FUNCION" : </font> $y=x^2 $

# %%
# prompt: grafica una paràbola

import matplotlib.pyplot as plt
import numpy as np

def function(x, y):
    plt.style.use("ggplot")
    fig, ax = plt.subplots(figsize=(8, 9))
    ax.plot(x, y, label="Parabola")  # Corrected label assignment

    ax.set_xlabel("Eje X")
    ax.set_ylabel("Eje Y")
    ax.set_title("Grafica de una parabola")
    ax.legend()
    plt.show()


# Example usage:
x = np.linspace(-5, 5, 100)  # Generate 100 points between -5 and 5
y = x**2  # Define the parabola equation (y = x^2)

function(x, y)

# %% [markdown]
# Imagen de gift

# %% [markdown]
# ![descarga 1.gif](data:image/gif;base64,...)
